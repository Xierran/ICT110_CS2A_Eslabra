# %% [markdown]
# # Chapter 1

# %% [markdown]
# ### Exercise 1

# %%
Print ('Hello world!')  #the p is in capital word
print 'Hello world!')   #there is no parentheses
print ('Hello world!)   #the is no quotation mark after the word World
print ('Hello world!'') #double qoutation in the end

# %%
print ('Hello world!')
print ('Hello world!')
print ('Hello world!')
print ('Hello world!')
# Out:
# Hello world!
# Hello world!
# Hello world!
# Hello world!

# %% [markdown]
# Exercise 2

# %%
x = 43
x = x + 1
print (x)
# Out:
# 44

# %% [markdown]
# Exercise 3

# %%
x = 43
x = X + 1
print(x)

# %%
x = 43
x = x + 1
print (x)
# Out:
# 44

# %%
# !git config --global user.name =  'Xierran'
# !git config --global user.email = 'mario.eslabra@students.isatu.edu.ph'
# !git config --global user.password = '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'

# %%
# !git clone https://Xierran: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@github.com/Xierran/ICT110_CS2A_Eslabra
# Out:
# Cloning into 'ICT110_CS2A_Eslabra'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 6 (delta 0), pack-reused 0
# Receiving objects: 100% (6/6), 4.83 KiB | 4.83 MiB/s, done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/Eslabra_Python_Workbook_1/Workbook_Chapter_1.ipynb" "/content/AppDev_Jamile/Workbook_1"

# %%
# %ls
# Out:
# drive/  ICT110_CS2A_Eslabra/  sample_data/
