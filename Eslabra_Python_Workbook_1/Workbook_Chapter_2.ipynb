# %% [markdown]
# # Chapter 2

# %% [markdown]
# ### Exercise 1

# %%
name = input("Enter your name: ")
print(name)
# Out:
# Enter your name: chunk
# chunk

# %% [markdown]
# Exercise 2

# %%
hours = input ("Enter Hours: ")
rate = input ("Enter Rate: ")
total = float(hours) * float(rate)
print ("Pay", total)
# Out:
# Enter Hours: 35
# Enter Rate: 2.75
# Pay 96.25

# %% [markdown]
# Exercise 3

# %%
width = 17
height = 12.0

print (width // 2)
print(type(width // 2))
print (width / 2.0)
print(type(width / 2.0))
print (height / 3)
print(type(height / 3))
print (1 + 2 * 5)
print(type(1 + 2 * 5))
# Out:
# 8
# <class 'int'>
# 8.5
# <class 'float'>
# 4.0
# <class 'float'>
# 11
# <class 'int'>

# %% [markdown]
# Exercise 4

# %%
a = input('Enter a number: ')
s =  int (a) ** 2
print('The square of', a, 'is', s)
# Out:
# Enter a number: 3
# The square of 3 is 9

# %% [markdown]
# CHALLENGE

# %%
celsius = float(input("Enter the temperature in Celsius: "))

fahrenheit = (celsius * 9/5) + 32

print(celsius, "Celsius is equivalent to:", round(fahrenheit, 2), "Fahrenheit")
# Out:
# Enter the temperature in Celsius: 36
# 36.0 Celsius is equivalent to: 96.8 Fahrenheit
