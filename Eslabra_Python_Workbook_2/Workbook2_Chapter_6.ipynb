# %% [markdown]
# # CHAPTER 6

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# Given the code below
#
#     text = 'Business Analytics'
#
# What will the following expressions produce?
#
#     text[4]
#     text[2:4]
#     text[:4]
#     text[4:]
#     text[-2]
#     text[-4:-2]
#     text[-2:]
#     text[:-2]

# %%
text = 'Business Analytics'

text[4]
print(text[4])      #n

text[2:4]
print(text[2:4])    #si

text[:4]
print(text[:4])     #Busi

text[4:]
print(text[4:])     #ness Analytics

text[-2]
print(text[-2])     #c

text[-4:-2]
print(text[-4:-2])  #ti

text[-2:]
print(text[-2:])    #cs

text[:-2]
print(text[:-2])    #Business Analyti
# Out:
# n
# si
# Busi
# ness Analytics
# c
# ti
# cs
# Business Analyti

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Given the code below:
#
#     phrase = 'One Ring to rule them all'
#
# What string slicing expression gives out the following words:
#
#     'One '
#     'Ring'
#     'all'
#     'them'
#     'One Ring to rule them all'

# %%
phrase = 'One Ring to rule them all'

print(phrase[:3])     #One
print(phrase[4:8])    #Ring
print(phrase[-3:])    #all
print(phrase[-8:-4])  #them
print(phrase[:])      #One Ring to rule them all
# Out:
# One
# Ring
# all
# them
# One Ring to rule them all

# %% [markdown]
# ## CHALLENGE

# %% [markdown]
# Write a program which repeatedly reads a **full name**, then does the following:
# - strips the name of any trailing spaces
# - capitalizes the first letter
# - puts the rest into smaller letters

# %%
def format_name(full_name):
    return full_name.strip().capitalize()

while True:
    full_name = input("Enter a full name: ")
    if full_name.lower() == 'quit':
        break
    formatted = format_name(full_name)
    print("Formatted name:", formatted)
# Out:
# Enter a full name: xiRRan yUKi viLLegas
# Formatted name: Xirran yuki villegas
# Enter a full name: quit
